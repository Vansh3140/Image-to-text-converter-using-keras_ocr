# %%
# !pip install keras-ocr
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.4/41.4 kB 3.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.5/9.5 MB 86.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 813.9/813.9 kB 69.4 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.7/50.7 kB 6.8 MB/s eta 0:00:00
# ...
#   Created wheel for validators: filename=validators-0.20.0-py3-none-any.whl size=19579 sha256=7d53bc83461cbbbbd2c3d4de18c5553d474d07aeaca997e1562bcc0fdfb9f0cc
#   Stored in directory: /root/.cache/pip/wheels/f2/ed/dd/d3a556ad245ef9dc570c6bcd2f22886d17b0b408dd3bbb9ac3
# Successfully built validators
# ...

# %%
import matplotlib.pyplot as plt
import keras_ocr
import pandas as pd
import numpy as np
import cv2
from google.colab.patches import cv2_imshow

# %%
pipeline=keras_ocr.pipeline.Pipeline()
# Out:
# Looking for /root/.keras-ocr/craft_mlt_25k.h5
# Looking for /root/.keras-ocr/crnn_kurapan.h5

# %%
img1=cv2.imread('/content/1.png')
img2=cv2.imread('/content/2.png')
img3=cv2.imread('/content/3.png')
img4=cv2.imread('/content/4.png')
img5=cv2.imread('/content/5.png')
img6=cv2.imread('/content/6.png')
img7=cv2.imread('/content/7.png')

# %%
cv2_imshow(img1)
# Out:
# <PIL.Image.Image image mode=RGB size=1280x1024 at 0x7FE87C311660>

# %%
prediction=pipeline.recognize([img1])
# Out:
# ...
# 1/1 [==============================] - 0s 64ms/step

# %%
prediction2=pipeline.recognize([img2])
# Out:
# ...
# 1/1 [==============================] - 2s 2s/step

# %%
prediction3=pipeline.recognize([img3])
# Out:
# ...
# 1/1 [==============================] - 0s 62ms/step

# %%
prediction4=pipeline.recognize([img4])
# Out:
# ...
# 1/1 [==============================] - 0s 63ms/step

# %%
prediction5=pipeline.recognize([img5])
# Out:
# ...
# 1/1 [==============================] - 2s 2s/step

# %%
prediction6=pipeline.recognize([img6])
# Out:
# ...
# 1/1 [==============================] - 0s 65ms/step

# %%
prediction7=pipeline.recognize([img7])
# Out:
# ...
# 1/1 [==============================] - 0s 66ms/step

# %%
keras_ocr.tools.drawAnnotations(cv2.imread('/content/1.png'),prediction[0])
# Out:
# <Axes: >

# %%
keras_ocr.tools.drawAnnotations(cv2.imread('/content/2.png'),prediction2[0])
# Out:
# <Axes: >

# %%
keras_ocr.tools.drawAnnotations(cv2.imread('/content/3.png'),prediction3[0])
# Out:
# <Axes: >

# %%
keras_ocr.tools.drawAnnotations(cv2.imread('/content/4.png'),prediction4[0])
# Out:
# <Axes: >

# %%
keras_ocr.tools.drawAnnotations(cv2.imread('/content/5.png'),prediction5[0])
# Out:
# <Axes: >

# %%
keras_ocr.tools.drawAnnotations(cv2.imread('/content/6.png'),prediction6[0])
# Out:
# <Axes: >

# %%
keras_ocr.tools.drawAnnotations(cv2.imread('/content/7.png'),prediction7[0])
# Out:
# <Axes: >
